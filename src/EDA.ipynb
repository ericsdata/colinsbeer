# %%
import pandas as pd 
import db_ec
import numpy as np

conn = db_ec.connect_db(r'..\data\beerdb.sqlite')

# %% [markdown]
# Look at number of reviews all the beer get

# %%
ff = db_ec.executeStatement(conn,'SELECT beerID, count(*) as rCount FROM reviews GROUP BY beerID',[])
np.log10(ff.rCount).hist()
# Out:
# <AxesSubplot:>
